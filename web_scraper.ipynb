# %%
class Faculty:
    def __init__(self, name, title, profile_url):
        self.name = name
        self.title = title
        self.profile_url = profile_url
        self.research_areas = []
        self.email = ""
        self.website = ""
        self.biography = ""

# %%
import requests
from bs4 import BeautifulSoup
import csv

def get_professor_data(faculty):
    # Fetch the page content

    url = faculty.profile_url
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Extract Name
    name_tag = soup.find('h1', class_='page-title')
    name = name_tag.span.text.strip() if name_tag else "N/A"

    # Extract Research Areas
    research_areas_tag = soup.find('strong', string="Research Areas:")
    if research_areas_tag:
       research_areas = research_areas_tag.find_parent('p').get_text(strip=True).replace('Research Areas:', '').strip()
    else:
        research_areas = []

    # Extract Email
    email_tag = soup.find('p', class_='card-block__text').find('a', href=lambda href: href and href.startswith('mailto:'))
    email = email_tag.get_text(strip=True) if email_tag else "N/A"

    # Extract Website
    website_tag = soup.find('p', class_='card-block__text').find('a', href=lambda href: href and href.startswith('http'))
    website = website_tag.get_text(strip=True) if website_tag else "N/A"

    # Extract Biography
    biography_tag = soup.find('div', class_='field--name-field-person-biography')
    biography = biography_tag.get_text(strip=True) if biography_tag else "N/A"

    faculty.research_areas = research_areas
    faculty.email = email
    faculty.website = website
    faculty.biography = biography

    return faculty

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://scs.gatech.edu/people/faculty/"

faculty_list = []
# Loop through each letter (A to Z)
for letter in "abcdefghijklmnopqrstuvwxyz":
    url = base_url + letter
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")

        # Find all faculty blocks
        faculty_blocks = soup.find_all("div", class_="profile-card__content")

        for faculty in faculty_blocks:
            name = faculty.find("h4", class_="card-block__title").get_text(strip=True)
            title = faculty.find("h6", class_="card-block__subtitle").get_text(strip=True)
            profile_url = "https://scs.gatech.edu" + faculty.find("a")["href"]

            faculty_det = Faculty(name, title, profile_url)
            faculty_det = get_professor_data(faculty_det)
            faculty_list.append(faculty_det)

            # Print the details
            print(f"Name: {faculty_det.name}")
            print(f"Title: {faculty_det.title}")
            print(f"Profile URL: {faculty_det.profile_url}")
            print(f"Research Areas: {faculty_det.research_areas}")
            print(f"Email: {faculty_det.email}")
            print(f"Website: {faculty_det.website}")
            print("-" * 40)
    else:
        print(f"Failed to retrieve the page for letter {letter}. Status code: {response.status_code}")
# Out:
# Name: Jacob Abernethy
# Title: Associate Professor
# Profile URL: https://scs.gatech.edu/people/jacob-abernethy
# Research Areas: Machine Learning
# Email: prof@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Mustaque Ahamad
# Title: USG Regents Entrepreneur Professor
# Profile URL: https://scs.gatech.edu/people/mustaque-ahamad
# Research Areas: Cybersecurity, Distributed Systems
# Email: mustaque.ahamad@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Mostafa Ammar
# Title: Regents' Professor, Interim Chair of SCS
# Profile URL: https://scs.gatech.edu/people/mostafa-ammar
# Research Areas: Networking
# Email: ammar@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Joy Arulraj
# Title: Associate Professor
# Profile URL: https://scs.gatech.edu/people/joy-arulraj
# Research Areas: Database systems, machine learning
# Email: jarulraj3@gatech.edu
# Website: N/A
# ----------------------------------------
# Name:
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/ling-liu
# Research Areas: Big Data systems and Analytics, Cloud Computing, Deep Learning, Distributed Systems, Mobile Computing, Privacy, Trust
# Email: ling.liu@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Divya Mahajan
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/divya-mahajan
# Research Areas: Computer Architecture, Systems for Machine Learning; Large Scale Infrastructure for AI and Data Storage
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Kuldeep S. Meel
# Title: Stephen Fleming Early-Career Associate Professor
# Profile URL: https://scs.gatech.edu/people/kuldeep-s-meel
# Research Areas: Automated Reasoning; Formal Methods; Databases; Foundations of AI
# Email: meel@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Amanda Meng
# Title: Research Scientist II
# Profile URL: https://scs.gatech.edu/people/amanda-meng
# Research Areas: []
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Amanda Meng
# Title: Research Scientist II
# Profile URL: https://scs.gatech.edu/people/amanda-meng-0
# Research Areas: []
# Email: a.meng@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Yisreol Mirsky
# Title: Post-Doc
# Profile URL: https://scs.gatech.edu/people/yisreol-mirsky
# Research Areas: []
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Steve Mussmann
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/steve-mussmann
# Research Areas: Data-centric machine learning; active labeling; data selection; adaptive experimental design
# Email: mussmann@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Shamkant Navathe
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/shamkant-navathe
# Research Areas: Data Modeling, Database Design, Data Integration, Data Mining, Data Visualization, Bioinformatics
# Email: sham@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Alessandro Orso
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/alessandro-orso
# Research Areas: Software Engineering
# Email: alessandro.orso@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Santosh Pande
# Title: Professor, Associate Chair for Graduate Studies,…
# Profile URL: https://scs.gatech.edu/people/santosh-pande
# Research Areas: Compiler Analysis and Optimizations
# Email: santosh@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Sunjae Park
# Title: Post-Doc
# Profile URL: https://scs.gatech.edu/people/sunjae-park
# Research Areas: []
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Sri Raj Paul
# Title: Post-Doc
# Profile URL: https://scs.gatech.edu/people/sri-raj-paul
# Research Areas: []
# Email: sriraj@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Paul Pearce
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/paul-pearce
# Research Areas: Cybersecurity
# Email: ppearce7@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Sterling Peet
# Title: Research Technologist II
# Profile URL: https://scs.gatech.edu/people/sterling-peet
# Research Areas: []
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Roberto Perdisci
# Title: Adjunct Assistant Professor
# Profile URL: https://scs.gatech.edu/people/roberto-perdisci
# Research Areas: Network and Web Security; AI Systems for Security
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Will Perkins
# Title: Associate Professor
# Profile URL: https://scs.gatech.edu/people/will-perkins
# Research Areas: Theory of Algorithms; Probability; Combinatorics
# Email: wperkins3@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Milos Prvulovic
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/milos-prvulovic
# Research Areas: Architecture, Information Security
# Email: milos.prvulovic@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Calton Pu
# Title: Professor and John P. Imlay, Jr. Chair in Software
# Profile URL: https://scs.gatech.edu/people/calton-pu
# Research Areas: Systems and databases
# Email: calton.pu@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Moinuddin Qureshi
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/moinuddin-qureshi
# Research Areas: Computer Architecture; Memory Systems; Hardware Security; Quantum Computing
# Email: moin@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Umakishore Ramachandran
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/umakishore-ramachandran
# Research Areas: Parallel and Distributed Systems
# Email: rama@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Dana Randall
# Title: ADVANCE Professor of Computing, Adjunct Professor…
# Profile URL: https://scs.gatech.edu/people/dana-randall
# Research Areas: Theory, Randomized algorithms
# Email: randall@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Kexin Rong
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/kexin-rong
# Research Areas: Database systems; machine learning
# Email: krong@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Ahmed Saeed
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/ahmed-saeed
# Research Areas: Datacenter systems; Computer networks; Operating systems
# Email: asaeed@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Brendan Saltaformaggio
# Title: Associate Professor in SCP, Joint with the School…
# Profile URL: https://scs.gatech.edu/people/brendan-saltaformaggio
# Research Areas: Cyber Forensics; Computer Systems Security; Threat Intelligence
# Email: brendan@ece.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Vivek Sarkar
# Title: Chair, School of Computer Science
# Profile URL: https://scs.gatech.edu/people/vivek-sarkar
# Research Areas: HPC, PL
# Email: vsarkar@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Jun Shirako
# Title: Senior Research Scientist
# Profile URL: https://scs.gatech.edu/people/jun-shirako
# Research Areas: []
# Email: shirako@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Sahil Singla
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/sahil-singla
# Research Areas: Algorithms and Uncertainty; Online Algorithms; Algorithmic Game Theory; Learning Theory
# Email: ssingla7@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Michael Specter
# Title: Assistant Professor in SCP, Joint with the School…
# Profile URL: https://scs.gatech.edu/people/michael-specter
# Research Areas: []
# Email: specter@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Cecilia Testart
# Title: Assistant Professor in SCP, Joint with the School…
# Profile URL: https://scs.gatech.edu/people/cecilia-testart
# Research Areas: Internet Measurements, Network Security, and Internet Policy
# Email: N/A
# Website: N/A
# ----------------------------------------
# Name: Alexey Tumanov
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/alexey-tumanov
# Research Areas: Systems for ML, resource management, and scheduling
# Email: atumanov@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Jan van den Brand
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/jan-van-den-brand
# Research Areas: Efficient Algorithms; Data Structures; Optimization
# Email: vdbrand@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Santosh Vempala
# Title: Frederick G. Storey Chair in Computing and…
# Profile URL: https://scs.gatech.edu/people/santosh-vempala
# Research Areas: Theory of algorithms, Foundations of Data Science, Theory of Brain, Computing for Good (C4G)
# Email: vempala@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Qi Xin
# Title: Post-Doc
# Profile URL: https://scs.gatech.edu/people/qi-xin
# Research Areas: []
# Email: qi.xin@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Jun Xu
# Title: Professor
# Profile URL: https://scs.gatech.edu/people/jun-xu
# Research Areas: Computer networking, cloud computing and networking, randomized algorithms
# Email: jx@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Guangliang Yang
# Title: Post-Doc
# Profile URL: https://scs.gatech.edu/people/guangliang-yang
# Research Areas: []
# Email: gyang63@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Jeffrey Young
# Title: Senior Research Scientist
# Profile URL: https://scs.gatech.edu/people/jeffrey-young
# Research Areas: High-performance algorithms and architectures.
# Email: jyoung9@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Ellen Zegura
# Title: Professor and Stephen Fleming Chair in…
# Profile URL: https://scs.gatech.edu/people/ellen-zegura
# Research Areas: Computer networking
# Email: ewz@cc.gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Qirun Zhang
# Title: Assistant Professor
# Profile URL: https://scs.gatech.edu/people/qirun-zhang
# Research Areas: programming languages, software engineering
# Email: qrzhang@gatech.edu
# Website: N/A
# ----------------------------------------
# Name: Jisheng Zhao
# Title: Senior Research Scientist
# Profile URL: https://scs.gatech.edu/people/jisheng-zhao
# Research Areas: []
# Email: N/A
# Website: N/A
# ----------------------------------------

# %%
with open('faculty_details.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Title", "Profile URL", "Research Areas", "Email", "Website", "Biography"])
    for faculty in faculty_list:
        writer.writerow([faculty.name, faculty.title, faculty.profile_url, faculty.research_areas, faculty.email, faculty.website, faculty.biography])
